# %% [markdown]
# ### ME4111 Scientific Compution and Machine Learning
#
# # Homework 2
#
# ### Due September 7

# %% [markdown]
# ### Problem 1
#
# Consider the Python code in Lecture2-pandas.ipynb, modify the code to conduct the following tasks:
# 1. Find the average highway fuel economy across all cars.
#
# 2. Find the manufacturer(s) and model(s) of the highest highway mpg (there could be more than one car). (hint: Consider using the np.max function.)
#
# 3. Find the average highway mpg by the car classification ‘class’ (compact, suv, etc)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Problems 2
#
# Find a solution of sin⁡(x) - x^2 = 0 in the interval [0.5, 1] where x is in radians.
#
# 1. Plot the function to inspect the location of the root.
# 2. Use the bisection method with a relative (approximate) error of 0.01.
# 3. Use the false position method with the same error level.
# 4. Observe and comment on the rate of convergence of both methods.

# %% [markdown]
# ## Problem 3
#
# Use the simple fixed-point iteration method to find a solution of f(x)= -0.2x^2 + 1.7x + 0.5 = 0, with an initial guess
# x_0=5.0 and relative (approximate) error of 0.01.
#
# Bonus Question (2 points): Try 2 other forms of g(x). Observe and comment on the relationship between the form of g(x), the initial guess, and the rate of convergence.
