# %% [markdown]
# ### ME4111 Scientific Computing and Machine Learning
#
# # Homework 3
#
# ### Due September 14

# %% [markdown]
# ## Problem 1
#
# Use Newton-Raphson to determine a real root for
#
# f(x) = 0.5x^3 - 4x^2 + 6x - 2
#
# Select initial guesses (a) 4.5 and (b) 4.43.
# 1. Be sure that the convergence criterion epstol = 1.0e-12 is satisfied.
# 2. Discuss any peculiarities in your results. Use graphical methods as required.

# %% [markdown]
# ## Problem 2
#
# Minimize the function
#
#  f(x) = x^4 + 2x^3 + 8x^2 + 5x + 1,       x ∈ [-2,1]
#
# Set the tolerance to be 1e-5.
#
# 1. Use the golden section method.
# 3. Plot f(x) to make sure that you get the correct minimization location.
# 4. Use scipy.optimize.minimize() to solve the same problem.

# %% [markdown]
# ## Problem 3
#
# Consider the function
#
# f(x) = sin(8x) + cos(3x) + 1,    x ∈ [3,6]
#
# 1. Plot the function over the interval [3,6], inspect how many roots exist.
# 2. Use Newton-Raphson to compute all roots. For each root you should select an initial guess that is close.
#
# Bonus Question (2 points): Write code to automatically bracket the roots and then compute them using Newton-Raphson. The bracketing interval should be sufficiently small so that the Newton-Raphson algorithm converges.
